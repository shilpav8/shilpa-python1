# %%
pip install langchain langchain-community langchain-openai chromadb pypdf
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/21.7 MB ? eta -:--:--
#    -------- ------------------------------- 4.7/21.7 MB 23.7 MB/s eta 0:00:01
#    -------------------- ------------------- 11.3/21.7 MB 27.1 MB/s eta 0:00:01
#    ------------------------------- -------- 17.3/21.7 MB 27.4 MB/s eta 0:00:01
#    ---------------------------------------  21.5/21.7 MB 28.2 MB/s eta 0:00:01
#    ---------------------------------------- 21.7/21.7 MB 25.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 4.7/4.7 MB 23.9 MB/s eta 0:00:00
# ...
